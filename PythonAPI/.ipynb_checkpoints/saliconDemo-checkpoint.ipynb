# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from salicon.salicon import SALICON
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt

# %%
dataDir='..'
dataType='val2014'
annFile='%s/annotations/fixations_%s_examples.json'%(dataDir,dataType)

# %%
# initialize COCO api for instance annotations
salicon=SALICON(annFile)
# Out:
# loading annotations into memory...
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-f1095099f558> in <module>()
#       1 # initialize COCO api for instance annotations
# ----> 2 salicon=SALICON(annFile)
#
# /home/shane/salicon/salicon/PythonAPI/salicon/salicon.py in __init__(self, annotation_file)
#      18         :return:
#      19         """
# ---> 20         COCO.__init__(self,annotation_file=annotation_file)
#      21
#      22
#
# /home/shane/salicon/salicon/PythonAPI/salicon/pycocotools/coco.py in __init__(self, annotation_file)
#      71             print 'loading annotations into memory...'
#      72             time_t = datetime.datetime.utcnow()
# ---> 73             dataset = json.load(open(annotation_file, 'r'))
#      74             print datetime.datetime.utcnow() - time_t
#      75             self.dataset = dataset
#
# IOError: [Errno 2] No such file or directory: './annotations/fixations_val2014_examples.json'

# %%
# get all images 
imgIds = salicon.getImgIds();
img = salicon.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]

# %%
# load and display image
I = io.imread('%s/images/examples/%s'%(dataDir,img['file_name']))
plt.figure()
plt.imshow(I)
plt.show()

# %%
# load and display instance annotations
#plt.imshow(I)
annIds = salicon.getAnnIds(imgIds=img['id'])
anns = salicon.loadAnns(annIds)
salicon.showAnns(anns)
plt.show()
